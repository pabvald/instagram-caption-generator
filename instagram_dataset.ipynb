# %%
from dataloaders.instagram import instagramDataset

# %%
ROOT = "data/datasets/instagram"

# %%
train_dataset = instagramDataset(root=ROOT, split="train")
val_dataset = instagramDataset(root=ROOT, split="val")
test_dataset = instagramDataset(root=ROOT, split="test")

{
    'train': len(train_dataset),
    'val': len(val_dataset),
    'test': len(test_dataset)
}
# Out:
# {'train': 8216, 'val': 2739, 'test': 2739}

# %%
img, caption, sr_no = train_dataset[0]
print(img)
print(caption)
print(sr_no)
# Out:
# tensor([[[2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#          [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#          [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#          ...,
#          [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#          [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489],
#          [2.2489, 2.2489, 2.2489,  ..., 2.2489, 2.2489, 2.2489]],
#
#         [[2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#          [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#          [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#          ...,
#          [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#          [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286],
#          [2.4286, 2.4286, 2.4286,  ..., 2.4286, 2.4286, 2.4286]],
#
#         [[2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
#          [2.6400, 2.6400, 2.6400,  ..., 2.6400, 2.6400, 2.6400],
# ...

# %%
train_dataset = instagramDataset(root=ROOT, split="train", is_transform=False)
img, caption, sr_no = train_dataset[0]
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x1350 at 0x7FD1209DF7C0>
